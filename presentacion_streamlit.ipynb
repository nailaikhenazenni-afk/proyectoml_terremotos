# %%
import streamlit as st
import pandas as pd
import numpy as np

# Configuración de la página en modo ancho y con título limpio
st.set_page_config(page_title="Presentación Riesgo Sísmico", layout="wide")

# Estilos personalizados para mantener el tono académico y elegante (Azul Profundo y Crema)
st.markdown("""
    <style>
    .main { background-color: #f3f0df; color: #005088; font-family: 'DM Sans', sans-serif; }
    h1, h2, h3 { color: #005088; font-family: 'Merriweather', serif; }
    .stButton>button { background-color: #005088; color: white; border-radius: 8px; }
    .highlight-box { background-color: white; padding: 25px; border-radius: 12px; border-left: 5px solid #11caa0; box-shadow: 0 4px 6px rgba(0,0,0,0.05); margin-bottom: 20px; }
    .metric-number { font-size: 48px; font-weight: bold; color: #11caa0; }
    </style>
""", unsafe_allow_html=True)

# --- BARRA LATERAL: NAVEGACIÓN DE DIAPOSITIVAS ---
st.sidebar.title("📌 Índice de Diapositivas")
opciones = [
    "1. Portada",
    "2. Descripción del Proyecto",
    "3. Selección y Preparación de Datos",
    "4. Ingeniería de Características",
    "5. Construcción y Evaluación de Modelos",
    "6. Sintonización de Hiperparámetros",
    "7. Hallazgos Clave y Validaciones",
    "8. Aplicación Real e Impacto",
    "9. Desafíos y Aprendizajes",
    "10. Trabajo Futuro",
    "11. Cierre y Preguntas"
]
diapositiva = st.sidebar.radio("Ir a:", opciones)

st.sidebar.markdown("---")
st.sidebar.info("💡 Usa este panel para navegar por la presentación durante tu defensa el viernes.")

# --- CONTENIDO DE LAS DIAPOSITIVAS ---

# 1. Portada
if diapositiva == "1. Portada":
    st.markdown("<br><br><br>", unsafe_allow_html=True)
    st.title("Clasificación y Predicción del Riesgo Sísmico Global")
    st.subheader("Modelización predictiva mediante técnicas avanzadas de Machine Learning")
    st.markdown("---")
    st.write("**Autora:** Naila Ikhenazen")
    st.write("**Fecha de Defensa:** Viernes")

# 2. Descripción del Proyecto
elif diapositiva == "2. Descripción del Proyecto":
    st.header("🏢 Descripción del Proyecto")
    st.markdown("<br>", unsafe_allow_html=True)
    col1, col2 = st.columns(2)
    with col1:
        st.markdown("""
        <div class="highlight-box">
            <h3>El Problema de Investigación</h3>
            <p>La clasificación automatizada de eventos sismológicos en categorías de riesgo (Moderado vs. Severo) para optimizar los sistemas de alerta temprana.</p>
        </div>
        """, unsafe_allow_html=True)
    with col2:
        st.markdown("""
        <div class="highlight-box">
            <h3>Objetivo e Impacto</h3>
            <p>Diseñar un ecosistema predictivo robusto que priorice la detección de la clase minoritaria crítica, transformando datos físicos continuos en directrices de seguridad civil.</p>
        </div>
        """, unsafe_allow_html=True)

# 3. Selección y Preparación de Datos
elif diapositiva == "3. Selección y Preparación de Datos":
    st.header("📊 Selección y Preparación de Datos")
    st.markdown("""
    * **Origen de los Datos:** Registros históricos globales de actividad sismológica.
    * **Características Clave:** Extremo desbalanceo en el conjunto de testeo. 
    """)
    
    # Simulación visual del desbalanceo crítico para que impacte al tribunal
    st.subheader("El Desafío Crítico: Distribución de Clases")
    datos_desbalanceo = pd.DataFrame({
        'Clase Símica': ['Moderados (0)', 'Severos (1)'],
        'Cantidad de Sismos': [6105, 110]
    })
    st.bar_chart(data=datos_desbalanceo, x='Clase Símica', y='Cantidad de Sismos', color="#005088")
    st.warning("⚠️ La clase severa representa únicamente el 1.7% del dataset total. Los modelos base tienden a ignorarla.")

# 4. Ingeniería de Características
elif diapositiva == "4. Ingeniería de Características":
    st.header("⚙️ Ingeniería de Características y Selección")
    
    st.markdown("""
    <div class="highlight-box">
        <h3>Variables Físicas Universales</h3>
        <p>Selección estratégica de variables continuas puras: <b>Magnitud, Profundidad (depth_km), Latitud y Longitud</b>.</p>
    </div>
    """, unsafe_allow_html=True)
    
    st.subheader("Justificación Metodológica: Descarte del Mapa de Localizaciones")
    st.markdown("""
    * **Redundancia Informativa:** La latitud y longitud ya ubican el evento de forma inequívoca. Incluir descripciones de texto (`localization_desc`) generaba multicolinealidad.
    * **Maldición de la Dimensionalidad:** Intentar procesar miles de categorías de texto generaba matrices dispersas ineficientes y desbordamientos de memoria (*MemoryError*).
    * **Capacidad de Generalización:** Al usar métricas puras, el modelo se mantiene exportable a cualquier nueva coordenada del mundo.
    """)

# 5. Construcción y Evaluación de Modelos
elif diapositiva == "5. Construcción y Evaluación de Modelos":
    st.header("🏗️ Construcción y Evaluación de Modelos")
    st.write("Estrategia experimental frente al desbalanceo de clases:")
    
    # Tabla interactiva con el resumen de tus resultados iniciales
    tabla_modelos = pd.DataFrame({
        'Modelo': ['Bagging Base', 'Random Forest Base', 'AdaBoost Base', 'Gradient Boosting', 'Random Forest (Tuned)'],
        'Recall (Clase Severa)': ['0.00', '0.00', '0.00', '0.02', '0.25'],
        'F1-Score (Clase Severa)': ['0.00', '0.00', '0.00', '0.03', '0.11'],
        'Accuracy Global': ['98%', '98%', '98%', '98%', '93%']
    })
    st.table(tabla_modelos)
    st.info("📌 Métrica Clave de Validación: Se descarta el Accuracy global (engañoso por el peso de la mayoría) y se adopta el F1-Score y el Recall.")

# 6. Sintonización de Hiperparámetros
elif diapositiva == "6. Sintonización de Hiperparámetros":
    st.header("🔧 Sintonización de Hiperparámetros")
    col1, col2 = st.columns(2)
    
    with col1:
        st.markdown("""
        <div class="highlight-box">
            <h3>Optimización de KNN</h3>
            <ul>
                <li><b>Métrica:</b> Manhattan (Bloques ortogonales)</li>
                <li><b>Vecinos:</b> 3 (Alta localización física)</li>
                <li><b>Pesos:</b> Distance (Inversamente proporcionales)</li>
            </ul>
            <p><b>Resultado:</b> Modelo definitivo con un score de 98.19% en test.</p>
        </div>
        """, unsafe_allow_html=True)
        
    with col2:
        st.markdown("""
        <div class="highlight-box">
            <h3>Corrección de Random Forest</h3>
            <ul>
                <li><b>Estrategia:</b> class_weight='balanced'</li>
                <li><b>Profundidad Máxima:</b> max_depth=10</li>
                <li><b>Criterio:</b> Gini</li>
            </ul>
            <p><b>Resultado:</b> Rescate de la ceguera algorítmica, elevando el recall crítico del 0% al 25%.</p>
        </div>
        """, unsafe_allow_html=True)

# 7. Hallazgos Clave y Validaciones
elif diapositiva == "7. Hallazgos Clave y Validaciones":
    st.header("💡 Hallazgos Clave e Insights")
    
    col1, col2 = st.columns(2)
    with col1:
        st.write("### Validación Estadística")
        st.markdown('<div class="metric-number">1.34e-67</div>', unsafe_allow_html=True)
        st.markdown("**p-valor de Chi-cuadrado:** Demuestra de manera concluyente que la distribución del riesgo sísmico responde a un patrón físico real y no al azar.")
        
    with col2:
        st.write("### Comportamiento No Lineal")
        st.markdown('<div class="metric-number">~ 0.00</div>', unsafe_allow_html=True)
        st.markdown("**Correlaciones de Pearson:** Las relaciones lineales entre variables aisladas son nulas, justificando por qué los modelos secuenciales y geométricos complejos son los únicos capaces de resolver el problema.")

# 8. Aplicación Real e Impacto
elif diapositiva == "8. Aplicación Real e Impacto":
    st.header("🌍 Aplicación en el Mundo Real")
    st.markdown("""
    <div class="highlight-box">
        <h3>Despliegue Sismológico</h3>
        <p>Integración en centrales de monitoreo y protección civil para zonificación automatizada del peligro.</p>
    </div>
    """, unsafe_allow_html=True)
    st.subheader("Ética y Criterio Técnico de Riesgos")
    st.error("🚨 En desastres naturales, un falso positivo implica costes de evacuación, pero un falso negativo (un sismo severo ignorado) cuesta vidas humanas. Por eso, el recall rescatado en el Random Forest es el verdadero éxito de ingeniería de este proyecto.")

# 9. Desafíos y Aprendizajes
elif diapositiva == "9. Desafíos y Aprendizajes":
    st.header("🏆 Desafíos y Aprendizajes Significativos")
    st.markdown("""
    * **Gestión del Desbalanceo:** Los algoritmos estándar están diseñados para la masa estadística; modificarlos a nivel de funciones de coste es vital.
    * **Auditoría de Recursos:** Resolución de cuellos de botella de hardware (*MemoryError*) mediante técnicas de reducción de dimensionalidad aplicadas al mapa de calor.
    * **Geometría vs. Árboles:** En problemas puramente geoespaciales, los modelos basados en vecindad matemática directa (KNN) demuestran una ventaja estructural innata frente a las particiones ortogonales básicas de los árboles.
    """)

# 10. Trabajo Futuro
elif diapositiva == "10. Trabajo Futuro":
    st.header("Trabajo Futuro y Mejoras")
    st.markdown("""
    * **Streaming de Datos:** Conectar la aplicación de Streamlit a flujos de datos en tiempo real mediante APIs de institutos sismológicos globales.
    * **Técnicas de Remuestreo avanzadas:** Implementar arquitecturas SMOTE o algoritmos combinados (EasyEnsemble) para intentar estirar el F1-score del Random Forest por encima del 0.11 actual.
    * **Modelos de Aprendizaje Profundo:** Experimentar con Redes Neuronales Artificiales (MLP) evaluando si las funciones de activación no lineales superan el rendimiento geométrico de KNN.
    """)

# 11. Cierre y Preguntas
elif diapositiva == "11. Cierre y Preguntas":
    st.markdown("<br><br><br>", unsafe_allow_html=True)
    st.title("¡Muchas gracias por su atención!")
    st.subheader("¿Tienen alguna pregunta o comentario?")
    st.markdown("---")
    st.info("💡 Consejo para el viernes: Deja esta pantalla fija mientras el tribunal debate o te formula las preguntas del examen.")
# Out:
# 2026-05-28 17:52:03.474 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-28 17:52:03.476 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-28 17:52:04.330
# ...
#   command:
#
#     streamlit run C:\Users\naila\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-28 17:52:04.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-28 17:52:04.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-28 17:52:04.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
